# %% [markdown]
# AULA 01 - COLAB COM PYTHON E PANDAS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
url = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                           Rua  \
# 66               Rua Major Alfredo Romão, 92
# 6838                                      NaN
# 1443                                      NaN
# 3848                      Rua Padre Marchetti
# 9855  Avenida Antônio de Souza Noschese, 996
# 5502                         Rua Santo Afonso
# 597                        Rua Maria Noschese
# 8449                                      NaN
# 3474                                      NaN
# 4104                         Avenida Amarilis
#
#                                   Bairro     Cidade  Metragem  Quartos  \
# 66                          Vila Clarice  São Paulo        99        3
# 6838                     Bosque da Saúde  São Paulo       486        3
# 1443                   Alto de Pinheiros  São Paulo       232        4
# 3848                            Ipiranga  São Paulo       150        2
# 9855                  Parque Continental  São Paulo       201        3
# 5502                     Penha de França  São Paulo      1100       10
# 597                    Jardim Novo Mundo  São Paulo       350        3
# 8449  Conjunto Residencial Morada do Sol  São Paulo       395        3
# 3474                      Jardim Guedala  São Paulo       595        5
# 4104                       Cidade Jardim  São Paulo      1000        5
#
#       Banheiros  Vagas         Valor
# 66            2      2    R$ 650.000
# 6838          1      1  R$ 1.900.000
# 1443          4      4  R$ 3.150.000
# 3848          3      2    R$ 550.000
# 9855          5      3    R$ 990.000
# 5502          8     10  R$ 3.500.000
# 597           4      6  R$ 3.100.000
# 8449          3      2  R$ 2.200.000
# 3474          8      6  R$ 6.000.000
# 4104          6      8  R$ 5.800.000

# %%
dados['Bairro'][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados['Metragem'].mean()
# Out:
# 442.30065947242207

# %%
vila_mariana = (dados['Bairro'] == 'Vila Mariana')

# %%
vila_mariana
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
dados['Bairro'].value_counts()
# Out:
# Bairro
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: count, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados['Bairro'].value_counts()
n_imoveis_bairro.head(10).plot.bar()
# Out:
# <Axes: xlabel='Bairro'>

# %%
media_bairro = dados.groupby('Bairro')['Metragem'].mean().reset_index()
media_bairro
# Out:
#                 Bairro    Metragem
# 0            Aclimação  253.056818
# 1    Alto da Boa Vista  418.875000
# 2         Alto da Lapa  294.337209
# 3        Alto da Mooca  270.050000
# 4    Alto de Pinheiros  433.444988
# ..                 ...         ...
# 696    Vila Água Funda  152.200000
# 697        Água Branca  191.000000
# 698          Água Fria  165.416667
# 699         Água Funda  139.000000
# 700          Água Rasa  340.250000
#
# [701 rows x 2 columns]

# %% [markdown]
# AULA 02 - TRATAMENTO DE DADOS E PRIMEIROS GRÁFICOS

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Valor'][0]
# Out:
# 'R$ 7.000.000'

# %%
dados.sample(10)
# Out:
#                                                    Rua              Bairro  \
# 9656              Rua Dona Maria Cândida de Lima, 133     Vila Paulo Silas
# 4293  Rua Desembargador Francisco Meirelles dos Santos  Jardim Santo Amaro
# 4507                                       Rua Mongóis      Vila Monumento
# 4690                    Rua Antônio de Gouveia Giudice   Alto de Pinheiros
# 2956                             Rua Enrico de Martino       Jardim Leonor
# 5923                    Rua Engenheiro Teixeira Soares             Butantã
# 1538     Rua Doutor Manuel Carlos de Figueiredo Ferraz      Jardim Morumbi
# 3241                              Praça Santos Coimbra             Morumbi
# 1537                               Rua Laerte Assunção   Jardim Paulistano
# 9729                                               NaN           Pinheiros
#
#          Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 9656  São Paulo       320        5          3      4
# 4293  São Paulo       540        3          6      4
# 4507  São Paulo       240        3          4      5
# 4690  São Paulo       366        4          4      4
# 2956  São Paulo       470        4          5      6
# 5923  São Paulo       488        3          5      3
# 1538  São Paulo       480        3          3      3
# 3241  São Paulo       450        4          5      6
# 1537  São Paulo       450        4          4      4
# 9729  São Paulo       425        4          7      6
#
#                                       Valor
# 9656                             R$ 520.000
# 4293  R$ 12.000\n                      /Mês
# 4507                           R$ 1.290.000
# 4690                           R$ 3.500.000
# 2956                           R$ 1.600.000
# 5923                           R$ 5.990.000
# 1538                           R$ 2.500.000
# 3241                           R$ 2.150.000
# 1537                           R$ 6.990.000
# 9729                           R$ 3.800.000

# %%
dados['Valor'].str.split(expand=True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados['Valor'].str.split(expand=True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
len(dados['Valor'].str.split(expand=True)[1].unique())
# Out:
# 1038

# %%
dados['Valor'].str.split(expand=True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[['Moeda', 'Valor_Anuncio', 'Tipo_anuncio']] = dados['Valor'].str.split(expand=True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados_vendas = dados[dados['Tipo_anuncio'].isnull()]

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 10002         None
# 10003         None
# 10004         None
# 10005         None
# 10007         None
#
# [9156 rows x 11 columns]

# %%
dados_vendas['Valor_Anuncio'].str.replace('.', '').astype(float)
# Out:
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_Anuncio, Length: 9156, dtype: float64

# %%
dados_vendas['Valor_Anuncio_Float'] = dados_vendas['Valor_Anuncio'].str.replace('.', '').astype(float)
dados_vendas
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18944\3052706691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_Anuncio_Float'] = dados_vendas['Valor_Anuncio'].str.replace('.', '').astype(float)
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$     7.000.000
# 1           496        4          4      4  R$ 3.700.000    R$     3.700.000
# 2           125        4          3      2    R$ 380.000    R$       380.000
# 3           310        3          2      4    R$ 685.000    R$       685.000
# 4           100        3          2      2    R$ 540.000    R$       540.000
# ...         ...      ...        ...    ...           ...   ...           ...
# 10002       267        3          6      4  R$ 1.500.000    R$     1.500.000
# 10003        95        2          2      2    R$ 665.000    R$       665.000
# 10004       605        8          7      5  R$ 2.300.000    R$     2.300.000
# 10005       205        3          3      6  R$ 1.050.000    R$     1.050.000
# 10007       122        3          2      2    R$ 270.000    R$       270.000
#
#       Tipo_anuncio  Valor_Anuncio_Float
# 0             None            7000000.0
# 1             None            3700000.0
# 2             None             380000.0
# 3             None             685000.0
# 4             None             540000.0
# ...            ...                  ...
# 10002         None            1500000.0
# 10003         None             665000.0
# 10004         None            2300000.0
# 10005         None            1050000.0
# 10007         None             270000.0
#
# [9156 rows x 12 columns]

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_Anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_Anuncio_Float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas['Valor_Anuncio_Float'].mean()
# Out:
# 3052202.9554390563

# %%
dados_vendas['Valor_Anuncio_Float'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dados_vendas.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_Anuncio_Float
# count         9.156000e+03
# mean          3.052203e+06
# std           3.944208e+06
# min           1.300000e+04
# 25%           8.900000e+05
# 50%           1.800000e+06
# 75%           3.500000e+06
# max           6.500000e+07

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x='Valor_Anuncio_Float', kde=True, color='Blue', bins=100)
ax.set_title('Histograma Valor Imóvel', fontsize=20)
plt.xlim((100000, 10000000))
ax.set_xlabel('Valor do Anúncio', fontsize=14)
ax.set_ylabel('Qtd de Imóveis', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid(False)
ax.set_frame_on(False)
plt.xscale('log')

def millions(x, pos):
    return '%1.1fM' % (x * 1e-6)

formatter = FuncFormatter(millions)
plt.gca().xaxis.set_major_formatter(formatter)

plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dados_vendas['Preco_m2'] = dados_vendas['Valor_Anuncio_Float'] / dados_vendas['Metragem']
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18944\2566136589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Preco_m2'] = dados_vendas['Valor_Anuncio_Float'] / dados_vendas['Metragem']

# %%
media_preco_m2_bairro = dados_vendas.groupby('Bairro')['Preco_m2'].mean().reset_index()
print(media_preco_m2_bairro)
# Out:
#                 Bairro      Preco_m2
# 0            Aclimação   7656.169465
# 1    Alto da Boa Vista   5849.569011
# 2         Alto da Lapa   7606.728080
# 3        Alto da Mooca   5691.740133
# 4    Alto de Pinheiros  11269.979971
# ..                 ...           ...
# 692    Vila Água Funda   4467.127995
# 693        Água Branca   7269.113912
# 694          Água Fria   5841.104428
# 695         Água Funda   3876.862745
# 696          Água Rasa   4509.608463
#
# [697 rows x 2 columns]

# %%
media_preco_m2_bairro
# Out:
#                 Bairro      Preco_m2
# 0            Aclimação   7656.169465
# 1    Alto da Boa Vista   5849.569011
# 2         Alto da Lapa   7606.728080
# 3        Alto da Mooca   5691.740133
# 4    Alto de Pinheiros  11269.979971
# ..                 ...           ...
# 692    Vila Água Funda   4467.127995
# 693        Água Branca   7269.113912
# 694          Água Fria   5841.104428
# 695         Água Funda   3876.862745
# 696          Água Rasa   4509.608463
#
# [697 rows x 2 columns]

# %%
sns.set_theme()
plt.figure(figsize=(10,8))
ax = sns.boxplot(data = media_preco_m2_bairro, x='Preco_m2')

# %% [markdown]
# AULA 03 - Gráficos, Time Series e Análise Exploratória

# %%
dados_vendas['Preco_m2'] = dados_vendas['Valor_Anuncio_Float']/dados_vendas['Metragem']
dados_vendas.head()
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_18944\44487277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Preco_m2'] = dados_vendas['Valor_Anuncio_Float']/dados_vendas['Metragem']
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_Anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_Anuncio_Float     Preco_m2
# 0            7000000.0  7000.000000
# 1            3700000.0  7459.677419
# 2             380000.0  3040.000000
# 3             685000.0  2209.677419
# 4             540000.0  5400.000000

# %%
dados_vendas.groupby('Bairro')['Preco_m2'].mean()
# Out:
# Bairro
# Aclimação             7656.169465
# Alto da Boa Vista     5849.569011
# Alto da Lapa          7606.728080
# Alto da Mooca         5691.740133
# Alto de Pinheiros    11269.979971
#                          ...
# Vila Água Funda       4467.127995
# Água Branca           7269.113912
# Água Fria             5841.104428
# Água Funda            3876.862745
# Água Rasa             4509.608463
# Name: Preco_m2, Length: 697, dtype: float64

# %%
media_preco_m2_bairro = dados_vendas.groupby('Bairro')['Preco_m2'].mean()
media_preco_m2_bairro.head()
# Out:
# Bairro
# Aclimação             7656.169465
# Alto da Boa Vista     5849.569011
# Alto da Lapa          7606.728080
# Alto da Mooca         5691.740133
# Alto de Pinheiros    11269.979971
# Name: Preco_m2, dtype: float64

# %%
dados_vendas.groupby('Bairro').sum()
# Out:
#                                                                  Rua  \
# Bairro
# Aclimação          Rua Ximbó, 410 Rua Alabastro, 151 Rua Carlos C...
# Alto da Boa Vista  Rua da Paz, 89 Rua Américo BrasilienseRua Amér...
# Alto da Lapa       Rua PeribebuíRua dos AliadosRua IagariRua Prin...
# Alto da Mooca      Rua Jupuruchita, 168 Rua Professor Oliveira Fa...
# Alto de Pinheiros  Rua Carlos Rath, 103 Rua Aquiramun, 94 Rua Aça...
# ...                                                              ...
# Vila Água Funda    Rua Joana Martins CastilhoRua Doutor Carneiro ...
# Água Branca        Rua Dona Germaine BurchardRua Lázaro Sousa Mar...
# Água Fria          Rua Marambá, 35 Rua Corneteiro JesusRua Antôni...
# Água Funda                                                         0
# Água Rasa          Rua Capitão João Rosa da CruzRua VergelRua Ita...
#
#                                                               Cidade  \
# Bairro
# Aclimação          São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Boa Vista  São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Lapa       São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Mooca      São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto de Pinheiros  São PauloSão PauloSão PauloSão PauloSão PauloS...
# ...                                                              ...
# Vila Água Funda        São PauloSão PauloSão PauloSão PauloSão Paulo
# Água Branca        São PauloSão PauloSão PauloSão PauloSão PauloS...
# Água Fria          São PauloSão PauloSão PauloSão PauloSão PauloS...
# Água Funda                                        São PauloSão Paulo
# Água Rasa          São PauloSão PauloSão PauloSão PauloSão PauloS...
#
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação             19447      258        240    230
# Alto da Boa Vista      3351       33         41     37
# Alto da Lapa          23940      252        308    320
# Alto da Mooca          5401       66         52     73
# Alto de Pinheiros    158616     1453       1782   1827
# ...                     ...      ...        ...    ...
# Vila Água Funda         761       13         11     13
# Água Branca            2083       37         39     27
# Água Fria              1985       34         41     30
# Água Funda              278        6          5      4
# Água Rasa              1117       16         12     22
#
#                                                                Valor  \
# Bairro
# Aclimação          R$ 800.000R$ 960.000R$ 2.200.000R$ 2.660.000R$...
# Alto da Boa Vista  R$ 1.680.000R$ 2.200.000R$ 2.200.000R$ 2.350.0...
# Alto da Lapa       R$ 2.200.000R$ 3.500.000R$ 2.400.000R$ 940.000...
# Alto da Mooca      R$ 1.049.400R$ 1.600.000R$ 1.300.000R$ 950.000...
# Alto de Pinheiros  R$ 2.900.000R$ 3.500.000R$ 5.500.000R$ 2.900.0...
# ...                                                              ...
# Vila Água Funda    R$ 540.000R$ 850.000R$ 850.000R$ 370.000R$ 650...
# Água Branca        R$ 1.300.000R$ 1.300.000R$ 1.300.000R$ 580.000...
# Água Fria          R$ 750.000R$ 1.270.000R$ 1.290.000R$ 1.300.000...
# Água Funda                                      R$ 660.000R$ 430.000
# Água Rasa          R$ 745.000R$ 625.000R$ 790.000R$ 745.000R$ 650...
#
#                                                                Moeda  \
# Bairro
# Aclimação          R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Boa Vista                                   R$R$R$R$R$R$R$R$
# Alto da Lapa       R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Mooca               R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$
# Alto de Pinheiros  R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# ...                                                              ...
# Vila Água Funda                                           R$R$R$R$R$
# Água Branca                                 R$R$R$R$R$R$R$R$R$R$R$R$
# Água Fria                                   R$R$R$R$R$R$R$R$R$R$R$R$
# Água Funda                                                      R$R$
# Água Rasa                                               R$R$R$R$R$R$
#
#                                                        Valor_Anuncio  \
# Bairro
# Aclimação          800.000960.0002.200.0002.660.0002.660.0001.400...
# Alto da Boa Vista  1.680.0002.200.0002.200.0002.350.0002.750.0003...
# Alto da Lapa       2.200.0003.500.0002.400.000940.0001.700.000949...
# Alto da Mooca      1.049.4001.600.0001.300.000950.000760.0001.300...
# Alto de Pinheiros  2.900.0003.500.0005.500.0002.900.0004.950.0006...
# ...                                                              ...
# Vila Água Funda                  540.000850.000850.000370.000650.000
# Água Branca        1.300.0001.300.0001.300.000580.0001.099.0001.0...
# Água Fria          750.0001.270.0001.290.0001.300.0001.290.000395...
# Água Funda                                            660.000430.000
# Água Rasa                 745.000625.000790.000745.000650.000742.000
#
#                   Tipo_anuncio  Valor_Anuncio_Float      Preco_m2
# Bairro
# Aclimação                    0         1.392928e+08  6.048374e+05
# Alto da Boa Vista            0         1.913000e+07  4.679655e+04
# Alto da Lapa                 0         1.666535e+08  6.085382e+05
# Alto da Mooca                0         2.368340e+07  1.138348e+05
# Alto de Pinheiros            0         1.764816e+09  4.158623e+06
# ...                        ...                  ...           ...
# Vila Água Funda              0         3.260000e+06  2.233564e+04
# Água Branca                  0         1.471800e+07  8.722937e+04
# Água Fria                    0         1.112500e+07  7.009325e+04
# Água Funda                   0         1.090000e+06  7.753725e+03
# Água Rasa                    0         4.297000e+06  2.705765e+04
#
# [697 rows x 12 columns]

# %%
dados_bairro = dados_vendas.groupby('Bairro').sum()
dados_bairro
# Out:
#                                                                  Rua  \
# Bairro
# Aclimação          Rua Ximbó, 410 Rua Alabastro, 151 Rua Carlos C...
# Alto da Boa Vista  Rua da Paz, 89 Rua Américo BrasilienseRua Amér...
# Alto da Lapa       Rua PeribebuíRua dos AliadosRua IagariRua Prin...
# Alto da Mooca      Rua Jupuruchita, 168 Rua Professor Oliveira Fa...
# Alto de Pinheiros  Rua Carlos Rath, 103 Rua Aquiramun, 94 Rua Aça...
# ...                                                              ...
# Vila Água Funda    Rua Joana Martins CastilhoRua Doutor Carneiro ...
# Água Branca        Rua Dona Germaine BurchardRua Lázaro Sousa Mar...
# Água Fria          Rua Marambá, 35 Rua Corneteiro JesusRua Antôni...
# Água Funda                                                         0
# Água Rasa          Rua Capitão João Rosa da CruzRua VergelRua Ita...
#
#                                                               Cidade  \
# Bairro
# Aclimação          São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Boa Vista  São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Lapa       São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Mooca      São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto de Pinheiros  São PauloSão PauloSão PauloSão PauloSão PauloS...
# ...                                                              ...
# Vila Água Funda        São PauloSão PauloSão PauloSão PauloSão Paulo
# Água Branca        São PauloSão PauloSão PauloSão PauloSão PauloS...
# Água Fria          São PauloSão PauloSão PauloSão PauloSão PauloS...
# Água Funda                                        São PauloSão Paulo
# Água Rasa          São PauloSão PauloSão PauloSão PauloSão PauloS...
#
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação             19447      258        240    230
# Alto da Boa Vista      3351       33         41     37
# Alto da Lapa          23940      252        308    320
# Alto da Mooca          5401       66         52     73
# Alto de Pinheiros    158616     1453       1782   1827
# ...                     ...      ...        ...    ...
# Vila Água Funda         761       13         11     13
# Água Branca            2083       37         39     27
# Água Fria              1985       34         41     30
# Água Funda              278        6          5      4
# Água Rasa              1117       16         12     22
#
#                                                                Valor  \
# Bairro
# Aclimação          R$ 800.000R$ 960.000R$ 2.200.000R$ 2.660.000R$...
# Alto da Boa Vista  R$ 1.680.000R$ 2.200.000R$ 2.200.000R$ 2.350.0...
# Alto da Lapa       R$ 2.200.000R$ 3.500.000R$ 2.400.000R$ 940.000...
# Alto da Mooca      R$ 1.049.400R$ 1.600.000R$ 1.300.000R$ 950.000...
# Alto de Pinheiros  R$ 2.900.000R$ 3.500.000R$ 5.500.000R$ 2.900.0...
# ...                                                              ...
# Vila Água Funda    R$ 540.000R$ 850.000R$ 850.000R$ 370.000R$ 650...
# Água Branca        R$ 1.300.000R$ 1.300.000R$ 1.300.000R$ 580.000...
# Água Fria          R$ 750.000R$ 1.270.000R$ 1.290.000R$ 1.300.000...
# Água Funda                                      R$ 660.000R$ 430.000
# Água Rasa          R$ 745.000R$ 625.000R$ 790.000R$ 745.000R$ 650...
#
#                                                                Moeda  \
# Bairro
# Aclimação          R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Boa Vista                                   R$R$R$R$R$R$R$R$
# Alto da Lapa       R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Mooca               R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$
# Alto de Pinheiros  R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# ...                                                              ...
# Vila Água Funda                                           R$R$R$R$R$
# Água Branca                                 R$R$R$R$R$R$R$R$R$R$R$R$
# Água Fria                                   R$R$R$R$R$R$R$R$R$R$R$R$
# Água Funda                                                      R$R$
# Água Rasa                                               R$R$R$R$R$R$
#
#                                                        Valor_Anuncio  \
# Bairro
# Aclimação          800.000960.0002.200.0002.660.0002.660.0001.400...
# Alto da Boa Vista  1.680.0002.200.0002.200.0002.350.0002.750.0003...
# Alto da Lapa       2.200.0003.500.0002.400.000940.0001.700.000949...
# Alto da Mooca      1.049.4001.600.0001.300.000950.000760.0001.300...
# Alto de Pinheiros  2.900.0003.500.0005.500.0002.900.0004.950.0006...
# ...                                                              ...
# Vila Água Funda                  540.000850.000850.000370.000650.000
# Água Branca        1.300.0001.300.0001.300.000580.0001.099.0001.0...
# Água Fria          750.0001.270.0001.290.0001.300.0001.290.000395...
# Água Funda                                            660.000430.000
# Água Rasa                 745.000625.000790.000745.000650.000742.000
#
#                   Tipo_anuncio  Valor_Anuncio_Float      Preco_m2
# Bairro
# Aclimação                    0         1.392928e+08  6.048374e+05
# Alto da Boa Vista            0         1.913000e+07  4.679655e+04
# Alto da Lapa                 0         1.666535e+08  6.085382e+05
# Alto da Mooca                0         2.368340e+07  1.138348e+05
# Alto de Pinheiros            0         1.764816e+09  4.158623e+06
# ...                        ...                  ...           ...
# Vila Água Funda              0         3.260000e+06  2.233564e+04
# Água Branca                  0         1.471800e+07  8.722937e+04
# Água Fria                    0         1.112500e+07  7.009325e+04
# Água Funda                   0         1.090000e+06  7.753725e+03
# Água Rasa                    0         4.297000e+06  2.705765e+04
#
# [697 rows x 12 columns]

# %%
dados_bairro['Valor_m2_bairro'] = dados_bairro['Valor_Anuncio_Float']/dados_bairro['Metragem']
dados_bairro.head()
# Out:
#                                                                  Rua  \
# Bairro
# Aclimação          Rua Ximbó, 410 Rua Alabastro, 151 Rua Carlos C...
# Alto da Boa Vista  Rua da Paz, 89 Rua Américo BrasilienseRua Amér...
# Alto da Lapa       Rua PeribebuíRua dos AliadosRua IagariRua Prin...
# Alto da Mooca      Rua Jupuruchita, 168 Rua Professor Oliveira Fa...
# Alto de Pinheiros  Rua Carlos Rath, 103 Rua Aquiramun, 94 Rua Aça...
#
#                                                               Cidade  \
# Bairro
# Aclimação          São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Boa Vista  São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Lapa       São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto da Mooca      São PauloSão PauloSão PauloSão PauloSão PauloS...
# Alto de Pinheiros  São PauloSão PauloSão PauloSão PauloSão PauloS...
#
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação             19447      258        240    230
# Alto da Boa Vista      3351       33         41     37
# Alto da Lapa          23940      252        308    320
# Alto da Mooca          5401       66         52     73
# Alto de Pinheiros    158616     1453       1782   1827
#
#                                                                Valor  \
# Bairro
# Aclimação          R$ 800.000R$ 960.000R$ 2.200.000R$ 2.660.000R$...
# Alto da Boa Vista  R$ 1.680.000R$ 2.200.000R$ 2.200.000R$ 2.350.0...
# Alto da Lapa       R$ 2.200.000R$ 3.500.000R$ 2.400.000R$ 940.000...
# Alto da Mooca      R$ 1.049.400R$ 1.600.000R$ 1.300.000R$ 950.000...
# Alto de Pinheiros  R$ 2.900.000R$ 3.500.000R$ 5.500.000R$ 2.900.0...
#
#                                                                Moeda  \
# Bairro
# Aclimação          R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Boa Vista                                   R$R$R$R$R$R$R$R$
# Alto da Lapa       R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Alto da Mooca               R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$
# Alto de Pinheiros  R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
#
#                                                        Valor_Anuncio  \
# Bairro
# Aclimação          800.000960.0002.200.0002.660.0002.660.0001.400...
# Alto da Boa Vista  1.680.0002.200.0002.200.0002.350.0002.750.0003...
# Alto da Lapa       2.200.0003.500.0002.400.000940.0001.700.000949...
# Alto da Mooca      1.049.4001.600.0001.300.000950.000760.0001.300...
# Alto de Pinheiros  2.900.0003.500.0005.500.0002.900.0004.950.0006...
#
#                   Tipo_anuncio  Valor_Anuncio_Float      Preco_m2  \
# Bairro
# Aclimação                    0         1.392928e+08  6.048374e+05
# Alto da Boa Vista            0         1.913000e+07  4.679655e+04
# Alto da Lapa                 0         1.666535e+08  6.085382e+05
# Alto da Mooca                0         2.368340e+07  1.138348e+05
# Alto de Pinheiros            0         1.764816e+09  4.158623e+06
#
#                    Valor_m2_bairro
# Bairro
# Aclimação              7162.688384
# Alto da Boa Vista      5708.743659
# Alto da Lapa           6961.299081
# Alto da Mooca          4385.002777
# Alto de Pinheiros     11126.342330

# %%
dados_bairro.loc['Vila Mariana']
# Out:
# Rua                    Rua Pero CorreiaPraça Doutor Carvalho FrancoRu...
# Cidade                 São PauloSão PauloSão PauloSão PauloSão PauloS...
# Metragem                                                           39079
# Quartos                                                              573
# Banheiros                                                            547
# Vagas                                                                499
# Valor                  R$ 1.350.000R$ 2.450.000R$ 1.490.000R$ 2.200.0...
# Moeda                  R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# Valor_Anuncio          1.350.0002.450.0001.490.0002.200.0001.700.0001...
# Tipo_anuncio                                                           0
# Valor_Anuncio_Float                                          299326000.0
# Preco_m2                                                   1337323.16224
# Valor_m2_bairro                                              7659.510223
# Name: Vila Mariana, dtype: object

# %%
top_bairros = dados_vendas['Bairro'].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace=True)
dados_bairro
# Out:
#                 Bairro                                                Rua  \
# 0            Aclimação  Rua Ximbó, 410 Rua Alabastro, 151 Rua Carlos C...
# 1    Alto da Boa Vista  Rua da Paz, 89 Rua Américo BrasilienseRua Amér...
# 2         Alto da Lapa  Rua PeribebuíRua dos AliadosRua IagariRua Prin...
# 3        Alto da Mooca  Rua Jupuruchita, 168 Rua Professor Oliveira Fa...
# 4    Alto de Pinheiros  Rua Carlos Rath, 103 Rua Aquiramun, 94 Rua Aça...
# ..                 ...                                                ...
# 692    Vila Água Funda  Rua Joana Martins CastilhoRua Doutor Carneiro ...
# 693        Água Branca  Rua Dona Germaine BurchardRua Lázaro Sousa Mar...
# 694          Água Fria  Rua Marambá, 35 Rua Corneteiro JesusRua Antôni...
# 695         Água Funda                                                  0
# 696          Água Rasa  Rua Capitão João Rosa da CruzRua VergelRua Ita...
#
#                                                 Cidade  Metragem  Quartos  \
# 0    São PauloSão PauloSão PauloSão PauloSão PauloS...     19447      258
# 1    São PauloSão PauloSão PauloSão PauloSão PauloS...      3351       33
# 2    São PauloSão PauloSão PauloSão PauloSão PauloS...     23940      252
# 3    São PauloSão PauloSão PauloSão PauloSão PauloS...      5401       66
# 4    São PauloSão PauloSão PauloSão PauloSão PauloS...    158616     1453
# ..                                                 ...       ...      ...
# 692      São PauloSão PauloSão PauloSão PauloSão Paulo       761       13
# 693  São PauloSão PauloSão PauloSão PauloSão PauloS...      2083       37
# 694  São PauloSão PauloSão PauloSão PauloSão PauloS...      1985       34
# 695                                 São PauloSão Paulo       278        6
# 696  São PauloSão PauloSão PauloSão PauloSão PauloS...      1117       16
#
#      Banheiros  Vagas                                              Valor  \
# 0          240    230  R$ 800.000R$ 960.000R$ 2.200.000R$ 2.660.000R$...
# 1           41     37  R$ 1.680.000R$ 2.200.000R$ 2.200.000R$ 2.350.0...
# 2          308    320  R$ 2.200.000R$ 3.500.000R$ 2.400.000R$ 940.000...
# 3           52     73  R$ 1.049.400R$ 1.600.000R$ 1.300.000R$ 950.000...
# 4         1782   1827  R$ 2.900.000R$ 3.500.000R$ 5.500.000R$ 2.900.0...
# ..         ...    ...                                                ...
# 692         11     13  R$ 540.000R$ 850.000R$ 850.000R$ 370.000R$ 650...
# 693         39     27  R$ 1.300.000R$ 1.300.000R$ 1.300.000R$ 580.000...
# 694         41     30  R$ 750.000R$ 1.270.000R$ 1.290.000R$ 1.300.000...
# 695          5      4                               R$ 660.000R$ 430.000
# 696         12     22  R$ 745.000R$ 625.000R$ 790.000R$ 745.000R$ 650...
#
#                                                  Moeda  \
# 0    R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# 1                                     R$R$R$R$R$R$R$R$
# 2    R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# 3             R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$
# 4    R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$R$...
# ..                                                 ...
# 692                                         R$R$R$R$R$
# 693                           R$R$R$R$R$R$R$R$R$R$R$R$
# 694                           R$R$R$R$R$R$R$R$R$R$R$R$
# 695                                               R$R$
# 696                                       R$R$R$R$R$R$
#
#                                          Valor_Anuncio Tipo_anuncio  \
# 0    800.000960.0002.200.0002.660.0002.660.0001.400...            0
# 1    1.680.0002.200.0002.200.0002.350.0002.750.0003...            0
# 2    2.200.0003.500.0002.400.000940.0001.700.000949...            0
# 3    1.049.4001.600.0001.300.000950.000760.0001.300...            0
# 4    2.900.0003.500.0005.500.0002.900.0004.950.0006...            0
# ..                                                 ...          ...
# 692                540.000850.000850.000370.000650.000            0
# 693  1.300.0001.300.0001.300.000580.0001.099.0001.0...            0
# 694  750.0001.270.0001.290.0001.300.0001.290.000395...            0
# 695                                     660.000430.000            0
# 696         745.000625.000790.000745.000650.000742.000            0
#
#      Valor_Anuncio_Float      Preco_m2  Valor_m2_bairro
# 0           1.392928e+08  6.048374e+05      7162.688384
# 1           1.913000e+07  4.679655e+04      5708.743659
# 2           1.666535e+08  6.085382e+05      6961.299081
# 3           2.368340e+07  1.138348e+05      4385.002777
# 4           1.764816e+09  4.158623e+06     11126.342330
# ..                   ...           ...              ...
# 692         3.260000e+06  2.233564e+04      4283.837057
# 693         1.471800e+07  8.722937e+04      7065.770523
# 694         1.112500e+07  7.009325e+04      5604.534005
# 695         1.090000e+06  7.753725e+03      3920.863309
# 696         4.297000e+06  2.705765e+04      3846.911370
#
# [697 rows x 14 columns]

# %%
plt.figure(figsize=(18,8))
ax = sns.barplot(x='Bairro', y='Valor_m2_bairro', data=dados_bairro.query('Bairro in @top_bairros'))
