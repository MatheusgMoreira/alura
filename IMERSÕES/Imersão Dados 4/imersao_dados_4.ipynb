# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'
dados = pd.read_csv(url)
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados['Bairro'][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Metragem'].mean()
# Out:
# 442.30065947242207

# %%
tem_imoveis_vila = (dados['Bairro'] == 'Vila Mariana')
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila = dados[tem_imoveis_vila]
imoveis_vila
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila['Metragem'].mean()
# Out:
# 233.6195652173913

# %%
dados['Bairro'].value_counts()
# Out:
# Bairro
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: count, Length: 701, dtype: int64

# %%
qtd_imoveis_bairro = dados['Bairro'].value_counts()
qtd_imoveis_bairro.head(10).plot.bar()
# Out:
# <Axes: xlabel='Bairro'>

# %%
media_metragem_bairro = dados.groupby('Bairro')['Metragem'].mean()
media_metragem_bairro
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
media_metragem_bairro.head(10).plot.bar()
# Out:
# <Axes: xlabel='Bairro'>

# %%
vila_mariana = dados.loc[dados['Bairro'] == 'Vila Mariana']
vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
media_metragem_bairro = dados.groupby('Bairro')['Vagas'].mean()
media_metragem_bairro.head(10).plot.pie()
# Out:
# <Axes: ylabel='Vagas'>

# %%
vila_mariana['Metragem'].describe()
# Out:
# count    184.000000
# mean     233.619565
# std       91.467315
# min       60.000000
# 25%      166.000000
# 50%      235.500000
# 75%      285.000000
# max      650.000000
# Name: Metragem, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Valor'][0]
# Out:
# 'R$ 7.000.000'

# %%
dados['Valor'][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                   Rua                   Bairro     Cidade  \
# 3605                Rua Pongada, 110           Jardim Panorama  São Paulo
# 8227                              NaN    Vila Brasílio Machado  São Paulo
# 780                               NaN                  Butantã  São Paulo
# 5624                      Rua Barueri              Vila Carrão  São Paulo
# 4757                              NaN          Jardim Paulista  São Paulo
# 8162       Avenida Marcondes de Brito  Chácara Seis de Outubro  São Paulo
# 3213                      Rua Banibás        Alto de Pinheiros  São Paulo
# 9337                              NaN        Vila Monte Alegre  São Paulo
# 6109  Rua Lázaro José Gonçalves, 164            Jardim Avelino  São Paulo
# 6675                   Rua Laiana, 6                   Boaçava  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 3605       394        4          6      4
# 8227       115        3          3      2
# ...

# %%
dados['Valor'].str.split(expand=True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados[['Moeda', 'Valor_anuncio', 'Tipo_anuncio' ]] = dados['Valor'].str.split(expand=True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados['Tipo_anuncio'].isnull()]['Tipo_anuncio'].unique()
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados_vendas = dados[dados['Tipo_anuncio'].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.', '').astype(float)
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_29808\3539278392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.', '').astype(float)

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   float64
#  10  Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %%
dados_vendas['Valor_anuncio'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dados_vendas['Valor_anuncio'].describe()
# Out:
# count       9156.00
# mean     3052202.96
# std      3944208.19
# min        13000.00
# 25%       890000.00
# 50%      1800000.00
# 75%      3500000.00
# max     65000000.00
# Name: Valor_anuncio, dtype: float64

# %%
dados_vendas[['Rua', 'Bairro', 'Cidade']].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
sns.set_theme()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x='Valor_anuncio', kde=True)
ax.set_title('Histograma Valor Imóvel')
plt.xlim((-50, 10000000))
plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   float64
#  10  Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %%
sns.set_theme()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x='Valor_anuncio', kde=True, color='purple')
ax.set_title('Histograma Valor Imóvel')
ax.set_ylabel('Qtd. Imóveis')
ax.set_xlabel('Valor do Anúncio')
plt.xlim((-50, 10000000))
plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dados_vendas['Preco_m2'] = dados_vendas['Valor_anuncio'] / dados_vendas['Metragem']
dados_vendas
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_29808\1504815475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Preco_m2'] = dados_vendas['Valor_anuncio'] / dados_vendas['Metragem']
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# ...

# %%
metro_quadrado_bairro = dados_vendas.groupby('Bairro').agg(
    Valor_total = ('Valor_anuncio', 'sum'),
    M2_total = ('Metragem', 'sum')
).reset_index()

# Agora, calcule a média de m2 depois de ter feito o agrupamento
metro_quadrado_bairro['Media_m2'] = metro_quadrado_bairro['Valor_total'] / metro_quadrado_bairro['M2_total']

metro_quadrado_bairro
# Out:
#                 Bairro   Valor_total  M2_total  Media_m2
# 0            Aclimação  139292801.00     19447   7162.69
# 1    Alto da Boa Vista   19130000.00      3351   5708.74
# 2         Alto da Lapa  166653500.00     23940   6961.30
# 3        Alto da Mooca   23683400.00      5401   4385.00
# 4    Alto de Pinheiros 1764815915.00    158616  11126.34
# ..                 ...           ...       ...       ...
# 692    Vila Água Funda    3260000.00       761   4283.84
# 693        Água Branca   14718000.00      2083   7065.77
# 694          Água Fria   11125000.00      1985   5604.53
# 695         Água Funda    1090000.00       278   3920.86
# 696          Água Rasa    4297000.00      1117   3846.91
#
# [697 rows x 4 columns]

# %%
top_bairros = dados_vendas['Bairro'].value_counts()[:10].index

# %%
metro_quadrado_bairro.query('Bairro in @top_bairros')
# Out:
#                 Bairro   Valor_total  M2_total  Media_m2
# 4    Alto de Pinheiros 1764815915.00    158616  11126.34
# 19   Brooklin Paulista  475796789.00     70002   6796.90
# 57       Cidade Jardim 1164210900.00    132220   8805.10
# 155      Jardim Europa 2414172900.00    118898  20304.57
# 168     Jardim Guedala 1801165587.00    972212   1852.65
# 187      Jardim Leonor  646326369.00     97141   6653.49
# 227    Jardim Paulista 2136081000.00    130283  16395.70
# 338           Pacaembu  867956500.00    100285   8654.90
# 396  Planalto Paulista  374907000.00     59250   6327.54
# 564      Vila Madalena  583253030.00     66250   8803.82

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data=metro_quadrado_bairro.query('Bairro in @top_bairros'), x='Bairro', y='Media_m2')
plt.title('Preço Médio por Metro Quadrado por Bairro')
plt.xlabel('Bairro')
plt.ylabel('Preço Médio por Metro Quadrado (R$)')
plt.xticks(rotation=45)
plt.show()

# %%
quartis = dados_vendas['Valor_anuncio'].quantile()
quartis
# Out:
# 1800000.0

# %%
mediana = dados_vendas['Valor_anuncio'].median()
mediana
# Out:
# 1800000.0

# %%
Q1 = dados_vendas['Valor_anuncio'].quantile(0.25)
Q3 = dados_vendas['Valor_anuncio'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = dados_vendas[(dados_vendas['Valor_anuncio'] < limite_inferior) | (dados_vendas['Valor_anuncio'] > limite_superior)]
outliers
# Out:
#                             Rua           Bairro     Cidade  Metragem  \
# 30             Rua dos Plátanos    Cidade Jardim  São Paulo      1195
# 67                  Rua Bolívia   Jardim América  São Paulo       663
# 68    Rua General Fonseca Teles  Jardim Paulista  São Paulo       420
# 102              Rua Inglaterra    Jardim Europa  São Paulo       756
# 108                         NaN  Jardim Paulista  São Paulo      1060
# ...                         ...              ...        ...       ...
# 9923                        NaN    Jardim Leonor  São Paulo      1345
# 9948        Rua Alvorada do Sul   Jardim Guedala  São Paulo       605
# 9959                        NaN    Jardim Leonor  São Paulo      1350
# 9984        Rua Alvorada do Sul   Jardim Guedala  São Paulo       605
# 9995                        NaN    Jardim Leonor  São Paulo      1350
#
#       Quartos  Banheiros  Vagas          Valor Moeda  Valor_anuncio  \
# ...

# %%
plt.figure(figsize=(12, 12))
sns.boxplot(data=dados_vendas['Valor_anuncio'])
plt.title("Boxplot com Quartis, Mediana e Outliers")
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxenplot(data=dados_vendas.query('Bairro in @top_bairros & Metragem < 30000'), x='Bairro', y='Metragem')
ax.tick_params(axis='x', rotation=45)
plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
link_ibge = 'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv'
dados_ibge = pd.read_csv(link_ibge, sep=';')
dados_ibge
# Out:
#              Cod_setor  Cod_Grandes Regi�es Nome_Grande_Regiao  Cod_UF  \
# 0      355030801000001                    3     Regi�o Sudeste      35
# 1      355030801000002                    3     Regi�o Sudeste      35
# 2      355030801000003                    3     Regi�o Sudeste      35
# 3      355030801000004                    3     Regi�o Sudeste      35
# 4      355030801000005                    3     Regi�o Sudeste      35
# ...                ...                  ...                ...     ...
# 18358  355030896000243                    3     Regi�o Sudeste      35
# 18359  355030896000244                    3     Regi�o Sudeste      35
# 18360  355030896000245                    3     Regi�o Sudeste      35
# 18361  355030896000246                    3     Regi�o Sudeste      35
# 18362  355030896000247                    3     Regi�o Sudeste      35
#
#       Nome_da_UF   Cod_meso                Nome_da_meso  Cod_micro  \
# ...

# %% [markdown]
# TENTAR VINCULAR DADOS DO IBGE COM OS DADOS DE IMÓVEIS
# TRATAR OS OUTLIERS
# REORGANIZAR ARQUIVOS
